# %%
#Import the packages to be used.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jlewis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopword_set = set(stopwords.words('english'))

# %%
#Import our data.
albumdf = pd.read_csv('atmosphere_album_data_2019', header=0)
songdf = pd.read_csv('atmosphere_song_lyrics_2019', header=0)

# %%
#Remove unwanted columns. Need to address the index column being saved in the csv files.
albumdf.drop(['Unnamed: 0', 'Songs'], axis=1, inplace=True)
songdf.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
#Create a length feature for each song, as well as a count of unique words, remove x2 and 2x from the lyrics
from collections import Counter
remove_words = ['slug', 'hook', 'verse', 'x2', '2x']
for word in remove_words:
    songdf['SongLyrics'] = songdf['SongLyrics'].apply(lambda words: words.replace(word, ''))
songdf['SongLyricsNS'] = songdf['SongLyrics'].apply(lambda words: (' '.join([w for w in words.split() if w not in stopword_set])))
songdf['WordCount'] = songdf['SongLyrics'].map(len)
songdf['UniqueWords'] = songdf['SongLyrics'].apply(lambda words: len(list(Counter(words.split()).keys())))

# %%
#Create the same two columns, but with stopwords removed
songdf['WordCountNS'] = songdf['SongLyrics'].apply(lambda words: len(' '.join([w for w in words.split() if w not in stopword_set])))
songdf['UniqueWordsNS'] = songdf['SongLyrics'].apply(lambda words: len(list(Counter([w for w in words.split() if w not in stopword_set]).keys())))

# %%
#Plot the new columns and compare them to the columns without stopwords
fig, ax = plt.subplots(ncols=3, sharey=True, figsize=(15,8))
songdf['WordCount'].hist(bins=20, alpha=0.7, ax=ax[0])
songdf['UniqueWords'].hist(bins=20, alpha=0.7, ax=ax[1])
ax[2].hist(x=100*(songdf['UniqueWords']/songdf['WordCount']), bins=20, alpha=0.7)
ax[0].set_xlabel('Number of Words in Song')
ax[1].set_xlabel('Number of Unique Words Used')
ax[2].set_xlabel('Pct of Unique Words')
songdf['WordCountNS'].hist(bins=20, color='red', alpha=0.5, ax=ax[0])
songdf['UniqueWordsNS'].hist(bins=20, color='red', alpha=0.5, ax=ax[1])
ax[2].hist(x=100*(songdf['UniqueWordsNS']/songdf['WordCountNS']), color='red', bins=20, alpha=0.5)
plt.suptitle('Word Counts')
plt.legend(('Stopwords', 'No Stopwords'))

# %% [markdown]
# So by removing the stopwords we reduce the number of words and number of unique words used, but the percentage
# of unique words rises.

# %%
#Lets make that percentage of unique words a new feature column
songdf['PctUnique'] = round(100*(songdf['UniqueWordsNS']/songdf['WordCountNS']), 3)

# %%
#Now I want to create a new df with information from the albumdf joined based on AlbumID.
joindf = songdf.merge(albumdf, on='AlbumID')
joindf.to_csv('atmospheredf', header=True)
joindf
# Out:
#                                     SongName  AlbumID  SongResponse  \
# 0                                       1597     7391           200
# 1                          Brief Description     7391           200
# 2                             Current Status     7391           200
# 3                              Complications     7391           200
# 4                                    4:30 AM     7391           200
# 5                                     Adjust     7391           200
# 6                                       Clay     7391           200
# 7                         Sound Is Vibration     7391           200
# 8                                  Multiples     7391           200
# 9                                  Scapegoat     7391           200
# 10                                       WND     7391           200
# 11                       Multiples (Reprise)     7391           200
# 12                                  Caved In     7391           200
# 13                     Cuando Limpia El Humo     7391           200
# 14                              The Outernet     7391           200
# 15                                    Primer     7391           200
# 16                         Between The Lines     5001           200
# 17                                Like Today     5001           200
# 18                       Tears For The Sheep     5001           200
# 19                       Guns And Cigarettes     5001           200
# 20          Don't Ever Fucking Question That     5001           200
# 21                                   It Goes     5001           200
# 22                      If I Was Santa Claus     5001           200
# 23                        Aspiring Sociopath     5001           200
# 24                              Free Or Dead     5001           200
# 25              Party For The Fight To Write     5001           200
# 26   Mama Had A Baby And His Head Popped Off     5001           200
# 27             They're All Gonna Laugh @ You     5001           200
# 28                            Lost And Found     5001           200
# 29         The Woman With The Tattooed Hands     5001           200
# ..                                       ...      ...           ...
# 218                                    Ringo    43755           200
# 219                                    Besos    43755           200
# 220                                Pure Evil    43755           200
# 221                                  Perfect    43755           200
# 222                            Seismic Waves    43755           200
# 223                              Next To You    43755           200
# 224         The Shit That We've Been Through    43755           200
# 225                   When The Lights Go Out    43755           200
# 226                                No Biggie    43755           200
# 227                               Everything    43755           200
# 228                         Chasing New York    43755           200
# 229                                    Sugar    43755           200
# 230                            Fishing Blues    43755           200
# 231                          Won't Look Back    43755           200
# 232                  Anybody That I've Known    43755           200
# 233                            Still Be Here    43755           200
# 234                             A Long Hello    43755           200
# 235                                   Jerome    60625           200
# 236                                Stopwatch    60625           200
# 237                                    Virgo    60625           200
# 238                                 Delicate    60625           200
# 239                                    Drown    60625           200
# 240                                  Anymore    60625           200
# 241                                  Earring    60625           200
# 242                                     Trim    60625           200
# 243                              Specificity    60625           200
# 244                                     Mijo    60625           200
# 245                               Randy Mosh    60625           200
# 246                                 Graffiti    60625           200
# 247                 Make It All Better Again    60625           200
#
#                                                SongURL  \
# 0            https://genius.com/Atmosphere-1597-lyrics
# 1    https://genius.com/Atmosphere-brief-descriptio...
# 2    https://genius.com/Atmosphere-current-status-l...
# 3    https://genius.com/Atmosphere-complications-ly...
# 4         https://genius.com/Atmosphere-4-30-am-lyrics
# 5          https://genius.com/Atmosphere-adjust-lyrics
# 6            https://genius.com/Atmosphere-clay-lyrics
# 7    https://genius.com/Atmosphere-sound-is-vibrati...
# 8       https://genius.com/Atmosphere-multiples-lyrics
# 9       https://genius.com/Atmosphere-scapegoat-lyrics
# 10            https://genius.com/Atmosphere-wnd-lyrics
# 11   https://genius.com/Atmosphere-multiples-repris...
# 12       https://genius.com/Atmosphere-caved-in-lyrics
# 13   https://genius.com/Atmosphere-cuando-limpia-el...
# 14   https://genius.com/Atmosphere-the-outernet-lyrics
# 15         https://genius.com/Atmosphere-primer-lyrics
# 16   https://genius.com/Atmosphere-between-the-line...
# 17     https://genius.com/Atmosphere-like-today-lyrics
# 18   https://genius.com/Atmosphere-tears-for-the-sh...
# 19   https://genius.com/Atmosphere-guns-and-cigaret...
# 20   https://genius.com/Atmosphere-dont-ever-fuckin...
# 21        https://genius.com/Atmosphere-it-goes-lyrics
# 22   https://genius.com/Atmosphere-if-i-was-santa-c...
# 23   https://genius.com/Atmosphere-aspiring-sociopa...
# 24   https://genius.com/Atmosphere-free-or-dead-lyrics
# 25   https://genius.com/Atmosphere-party-for-the-fi...
# 26   https://genius.com/Atmosphere-mama-had-a-baby-...
# 27   https://genius.com/Atmosphere-theyre-all-gonna...
# 28   https://genius.com/Atmosphere-modern-mans-hust...
# 29   https://genius.com/Atmosphere-the-woman-with-t...
# ..                                                 ...
# 218         https://genius.com/Atmosphere-ringo-lyrics
# 219         https://genius.com/Atmosphere-besos-lyrics
# 220     https://genius.com/Atmosphere-pure-evil-lyrics
# 221       https://genius.com/Atmosphere-perfect-lyrics
# 222  https://genius.com/Atmosphere-seismic-waves-ly...
# 223   https://genius.com/Atmosphere-next-to-you-lyrics
# 224  https://genius.com/Atmosphere-the-shit-that-we...
# 225  https://genius.com/Atmosphere-when-the-lights-...
# 226     https://genius.com/Atmosphere-no-biggie-lyrics
# 227    https://genius.com/Atmosphere-everything-lyrics
# 228  https://genius.com/Atmosphere-chasing-new-york...
# 229         https://genius.com/Atmosphere-sugar-lyrics
# 230  https://genius.com/Atmosphere-fishing-blues-ly...
# 231  https://genius.com/Atmosphere-wont-look-back-l...
# 232  https://genius.com/Atmosphere-anybody-that-ive...
# 233  https://genius.com/Atmosphere-still-be-here-ly...
# 234  https://genius.com/Atmosphere-a-long-hello-lyrics
# 235        https://genius.com/Atmosphere-jerome-lyrics
# 236     https://genius.com/Atmosphere-stopwatch-lyrics
# 237         https://genius.com/Atmosphere-virgo-lyrics
# 238      https://genius.com/Atmosphere-delicate-lyrics
# 239         https://genius.com/Atmosphere-drown-lyrics
# 240       https://genius.com/Atmosphere-anymore-lyrics
# 241       https://genius.com/Atmosphere-earring-lyrics
# 242          https://genius.com/Atmosphere-trim-lyrics
# 243   https://genius.com/Atmosphere-specificity-lyrics
# 244          https://genius.com/Atmosphere-mijo-lyrics
# 245    https://genius.com/Atmosphere-randy-mosh-lyrics
# 246      https://genius.com/Atmosphere-graffiti-lyrics
# 247  https://genius.com/Atmosphere-make-it-all-bett...
#
#                                             SongLyrics  \
# 0      henceforth step within my psychoanalysis cal...
# 1     sample have you heard it sing along if you di...
# 2     beyond now known as musab i peep rap city hig...
# 3     intro spawn spoken yo this is dedicated to th...
# 4     el p so tootsie roll the fuck back to your se...
# 5      1  i woke up on the wrong side of my head co...
# 6      1  when i first landed the damage was outlan...
# 7      im sparked waiting for the dark to hit cause...
# 8     sample lionel hampton right now we gonna get ...
# 9      1  its the caffeine the nicotine the milligr...
# 10     its summer and im chilling on my steps with ...
# 11     my afterword analysis was the average made m...
# 12     1 spawn the door opened in walked my brother...
# 13     1  spawn patterned around the thought and th...
# 14     for starters i contemplated on where to spli...
# 15    begin hey daley get the fuck away from my sis...
# 16    what it is it aint and what it aint it is its...
# 17    in tomorrow i see no promise and yesterday wa...
# 18     1  a city of fools i wanna bash whoevers res...
# 19     whats your name fool rappers stepping to me ...
# 20     1  enough to hold you to the brightest of li...
# 21     1 now when you come to apply for a job dont ...
# 22     if i was a rich man id buy you some shoes ta...
# 23     7 30 am alerted to life by a song on the rad...
# 24    so here i am trying to be the man right using...
# 25     hides the eyes beneath the bill of the cap w...
# 26    trying to lift her pull her  1  six six six i...
# 27     youd better find a way youd better do it soo...
# 28     1  the first time i met the devil was at a m...
# 29    only   i used to know this woman who had the ...
# ..                                                 ...
# 218    1 i think im still drunk from last night i w...
# 219    1  one up never still if the sun up its all ...
# 220   chorus i b e no no no no no oh no no no i don...
# 221    1 fall from the sky just to learn how to fly...
# 222    1 armageddon started i guess it wasnt that h...
# 223    dem atlas darlin you dont even know im layin...
# 224    1  seven in the morning locked the door put ...
# 225    1  do you remember that knife you wouldnt pa...
# 226     she said no biggie territorial enough to tr...
# 227    1 when i was younger i didnt think that i wo...
# 228    1  i used to be in love with brooklyn way be...
# 229   intro youre such a sweet thing youre such a s...
# 230    1  i realize that we aint the same but you m...
# 231    kim manning any way that the cold wind blows...
# 232    in my past i d wish for something different ...
# 233    1 i didn t believe that i could have anythin...
# 234   intro lets make a bonfire i got a blanket in ...
# 235    1 i aint the one i never was the one just an...
# 236    1 yes and i guess its just a sign that im a ...
# 237    1 i pledge allegiance to myself food shelter...
# 238    that little kid in the windows looking out a...
# 239    1  i knew that i couldnt survive without you...
# 240    1 uh i cant listen if you cant be accountabl...
# 241   intro kim manning la la la la la laa la laa l...
# 242   chorus we gotta get it whenever we can i cant...
# 243   intro specificity specificity and you should ...
# 244    1 it was a dark and stormy night puddles of ...
# 245   chorus i self devine as the sun sets the moon...
# 246    1 i wrote this one when i was still alive he...
# 247    1 and aint nobody seen him around anymore ev...
#
#                                           SongLyricsNS  WordCount  \
# 0    henceforth step within psychoanalysis callouse...       2828
# 1    sample heard sing along didnt hear youre gonna...       4504
# 2    beyond known musab peep rap city highlights ey...       3111
# 3    intro spawn spoken yo dedicated girl dated com...       3688
# 4    el p tootsie roll fuck back seat cause dont li...       2572
# 5    1 woke wrong side head converts day search awa...       4209
# 6    1 first landed damage outlandish anguish anxio...       2718
# 7    im sparked waiting dark hit cause moon gets ap...       3796
# 8    sample lionel hampton right gonna get together...       3121
# 9    1 caffeine nicotine milligrams tar habitat nee...       2653
# 10   summer im chilling steps little crew like vide...       2718
# 11   afterword analysis average made anxious began ...       1584
# 12   1 spawn door opened walked brother terrified t...       2096
# 13   1 spawn patterned around thought shattered sou...       3798
# 14   starters contemplated split marked spot dotted...       3893
# 15   begin hey daley get fuck away sister punk moth...       2368
# 16   aint aint theme goin 1 see police man notice l...       3566
# 17   tomorrow see promise yesterday like today woke...       3286
# 18   1 city fools wanna bash whoevers responsible i...       3616
# 19   whats name fool rappers stepping wanna get go ...       2866
# 20   1 enough hold brightest lights place dangerous...       2790
# 21   1 come apply job dont tell em youre homeless c...       3160
# 22   rich man id buy shoes tall boots dirt walk wou...       3028
# 23   7 30 alerted life song radio evening another m...       3396
# 24   trying man right using gun see night sleeping ...       3688
# 25   hides eyes beneath bill cap walks amongst flie...       2823
# 26   trying lift pull 1 six six six mornin im takin...       2706
# 27   youd better find way youd better soon like mid...       1944
# 28   1 first time met devil motel 6 left hell spend...       3333
# 29   used know woman beautiful tattoos top sides ha...       2814
# ..                                                 ...        ...
# 218  1 think im still drunk last night woke lawn ch...       2936
# 219  1 one never still sun love gov see come like j...       2547
# 220  chorus b e oh dont believe dont believe oh pur...       1490
# 221  1 fall sky learn fly dont even gotta put dirt ...       2486
# 222  1 armageddon started guess wasnt hard miss did...       2466
# 223  dem atlas darlin dont even know im layin right...       1943
# 224  1 seven morning locked door put keys bag next ...       1858
# 225  1 remember knife wouldnt part kept sharp carve...       2510
# 226  said biggie territorial enough try build wall ...       1562
# 227  1 younger didnt think would live long ive livi...       2254
# 228  1 used love brooklyn way ever got go brooklyn ...       2683
# 229  intro youre sweet thing youre sweet thing your...       2495
# 230  1 realize aint might appreciate try explain im...       1995
# 231  kim manning way cold wind blows ill go cause r...       3565
# 232  past wish something different whats within gra...       2233
# 233  1 believe could anything else share mean knew ...       2097
# 234  intro lets make bonfire got blanket trunk one ...       1990
# 235  1 aint one never one another son son gun grand...       2074
# 236  1 yes guess sign im pessimist life limited tim...       2584
# 237  1 pledge allegiance food shelter health let fi...       1691
# 238  little kid windows looking winter like whole w...       2277
# 239  1 knew couldnt survive without side im alive t...       2519
# 240  1 uh cant listen cant accountable im competiti...       2287
# 241  intro kim manning la la la la la laa la laa la...       1997
# 242  chorus gotta get whenever cant wait til end we...       2483
# 243  intro specificity specificity try see us live ...       1371
# 244  1 dark stormy night puddles rain reflected sto...       2177
# 245  chorus self devine sun sets moon rises vengean...       3899
# 246  1 wrote one still alive hey yeah listen horse ...       2146
# 247  1 aint nobody seen around anymore ever since l...       2719
#
#      UniqueWords  WordCountNS  UniqueWordsNS  PctUnique  \
# 0            300         1869            242     12.948
# 1            425         2844            349     12.271
# 2            312         2008            256     12.749
# 3            326         2356            264     11.205
# 4            273         1613            214     13.267
# 5            357         2849            292     10.249
# 6            302         1736            240     13.825
# 7            374         2510            311     12.390
# 8            286         2004            231     11.527
# 9            264         1674            231     13.799
# 10           246         1683            194     11.527
# 11           177         1041            141     13.545
# 12           244         1347            188     13.957
# 13           352         2512            290     11.545
# 14           335         2540            270     10.630
# 15           265         1512            208     13.757
# 16           323         2324            263     11.317
# 17           311         2109            243     11.522
# 18           305         2303            247     10.725
# 19           304         1877            236     12.573
# 20           267         1838            213     11.589
# 21           332         2023            262     12.951
# 22           266         1874            211     11.259
# 23           271         2242            210      9.367
# 24           393         2481            329     13.261
# 25           290         1754            230     13.113
# 26           285         1569            220     14.022
# 27           225         1341            181     13.497
# 28           270         2069            214     10.343
# 29           220         1759            162      9.210
# ..           ...          ...            ...        ...
# 218          226         2153            174      8.082
# 219          267         1769            213     12.041
# 220          151          865            105     12.139
# 221          240         1590            184     11.572
# 222          250         1686            204     12.100
# 223          184         1251            136     10.871
# 224          166         1121            129     11.508
# 225          240         1505            185     12.292
# 226          174         1016            132     12.992
# 227          206         1359            150     11.038
# 228          215         1714            169      9.860
# 229          216         1559            167     10.712
# 230          179         1393            140     10.050
# 231          253         2369            196      8.274
# 232          188         1457            138      9.472
# 233          218         1173            159     13.555
# 234          209         1270            156     12.283
# 235          233         1283            178     13.874
# 236          233         1596            175     10.965
# 237          203         1163            160     13.758
# 238          213         1444            159     11.011
# 239          242         1550            181     11.677
# 240          207         1628            164     10.074
# 241          198         1412            148     10.482
# 242          191         1582            146      9.229
# 243          158          844            112     13.270
# 244          196         1411            154     10.914
# 245          388         2785            327     11.741
# 246          213         1376            157     11.410
# 247          215         1703            161      9.454
#
#                          AlbumName  Year
# 0                        Overcast!  1997
# 1                        Overcast!  1997
# 2                        Overcast!  1997
# 3                        Overcast!  1997
# 4                        Overcast!  1997
# 5                        Overcast!  1997
# 6                        Overcast!  1997
# 7                        Overcast!  1997
# 8                        Overcast!  1997
# 9                        Overcast!  1997
# 10                       Overcast!  1997
# 11                       Overcast!  1997
# 12                       Overcast!  1997
# 13                       Overcast!  1997
# 14                       Overcast!  1997
# 15                       Overcast!  1997
# 16   Lucy Ford: The Atmosphere EPs  2001
# 17   Lucy Ford: The Atmosphere EPs  2001
# 18   Lucy Ford: The Atmosphere EPs  2001
# 19   Lucy Ford: The Atmosphere EPs  2001
# 20   Lucy Ford: The Atmosphere EPs  2001
# 21   Lucy Ford: The Atmosphere EPs  2001
# 22   Lucy Ford: The Atmosphere EPs  2001
# 23   Lucy Ford: The Atmosphere EPs  2001
# 24   Lucy Ford: The Atmosphere EPs  2001
# 25   Lucy Ford: The Atmosphere EPs  2001
# 26   Lucy Ford: The Atmosphere EPs  2001
# 27   Lucy Ford: The Atmosphere EPs  2001
# 28   Lucy Ford: The Atmosphere EPs  2001
# 29   Lucy Ford: The Atmosphere EPs  2001
# ..                             ...   ...
# 218                  Fishing Blues  2016
# 219                  Fishing Blues  2016
# 220                  Fishing Blues  2016
# 221                  Fishing Blues  2016
# 222                  Fishing Blues  2016
# 223                  Fishing Blues  2016
# 224                  Fishing Blues  2016
# 225                  Fishing Blues  2016
# 226                  Fishing Blues  2016
# 227                  Fishing Blues  2016
# 228                  Fishing Blues  2016
# 229                  Fishing Blues  2016
# 230                  Fishing Blues  2016
# 231                  Fishing Blues  2016
# 232                  Fishing Blues  2016
# 233                  Fishing Blues  2016
# 234                  Fishing Blues  2016
# 235                  Mi Vida Local  2018
# 236                  Mi Vida Local  2018
# 237                  Mi Vida Local  2018
# 238                  Mi Vida Local  2018
# 239                  Mi Vida Local  2018
# 240                  Mi Vida Local  2018
# 241                  Mi Vida Local  2018
# 242                  Mi Vida Local  2018
# 243                  Mi Vida Local  2018
# 244                  Mi Vida Local  2018
# 245                  Mi Vida Local  2018
# 246                  Mi Vida Local  2018
# 247                  Mi Vida Local  2018
#
# [248 rows x 13 columns]

# %%
#Check the top 5 in word count and unique words
print(joindf[['SongName', 'AlbumName', 'WordCountNS', 'UniqueWordsNS', 'PctUnique']].sort_values(by='WordCountNS', axis=0, ascending=False).head(5))
print('\n')
print(joindf[['SongName', 'AlbumName', 'WordCountNS', 'UniqueWordsNS', 'PctUnique']].sort_values(by='UniqueWordsNS', axis=0, ascending=False).head(5))
print('\n')
print(joindf[['SongName', 'AlbumName', 'WordCountNS', 'UniqueWordsNS', 'PctUnique']].sort_values(by='PctUnique', axis=0, ascending=False).head(5))
# Out:
#                       SongName         AlbumName  WordCountNS  UniqueWordsNS  \
# 70   Sep Seven Game Show Theme  Headshots: SE7EN         3112            371
# 135                  Crewed Up  Strictly Leakage         2987            388
# 74    The Jackpot / Swept Away  Headshots: SE7EN         2985            360
# 37                Godlovesugly    God Loves Ugly         2883            262
# 5                       Adjust         Overcast!         2849            292
#
#      PctUnique
# 70      11.922
# 135     12.990
# 74      12.060
# 37       9.088
# 5       10.249
#
#
#                       SongName                      AlbumName  WordCountNS  \
# 135                  Crewed Up               Strictly Leakage         2987
# 70   Sep Seven Game Show Theme               Headshots: SE7EN         3112
# 74    The Jackpot / Swept Away               Headshots: SE7EN         2985
# 1            Brief Description                      Overcast!         2844
# 24                Free Or Dead  Lucy Ford: The Atmosphere EPs         2481
#
#      UniqueWordsNS  PctUnique
# 135            388     12.990
# 70             371     11.922
# 74             360     12.060
# 1              349     12.271
# 24             329     13.261
#
#
#                    SongName         AlbumName  WordCountNS  UniqueWordsNS  \
# 82                Anterlude  Headshots: SE7EN          102             18
# 181                  My Key   The Family Sign          727            117
# 58                    Jason   Seven's Travels          240             38
# 136  What They Sitting For?  Strictly Leakage          883            133
# 194                My Notes   The Family Sign          679            102
#
#      PctUnique
# 82      17.647
# 181     16.094
# 58      15.833
# 136     15.062
# 194     15.022

# %%
#Going to create a colour palette to separate each album.
album_cplot = sns.hls_palette(joindf['AlbumName'].nunique(), l=0.55, s=1)
album_cdict = dict(zip(joindf['AlbumName'].unique().tolist(), album_cplot))
sns.palplot(album_cplot)

# %%
#Now define a function to plot the top 'n' from 'column' in the dataframe.
def topNPlot(column, topn, ax):
    df = joindf.sort_values(by=column, axis=0, ascending=False).head(topn)
    x = df['SongName']
    y = df[column]
    p = sns.barplot(x=x, y=y, data=df, ci=0, hue='AlbumName', palette=album_cdict, dodge=False, ax=ax)
    p.legend_ = None
    plt.tight_layout()

# %%
#Lets see if there's overlap between the top 10 in pct of unique, unique words used, and words used.
fig, ax = plt.subplots(ncols=3, figsize=(18,8))
topNPlot('PctUnique', 10, ax[0])
topNPlot('UniqueWordsNS', 10, ax[1])
topNPlot('WordCountNS', 10, ax[2])
for ax in fig.axes:
    plt.sca(ax)
    plt.xticks(rotation=90)

# %% [markdown]
# Surprising. There's no overlap between the percentage of unique words used, and the total unique or total words used. There's a lot of overlap betwen total unique and total words though which makes sense.

# %%
#Lets see how each album compares. We can plot each song in each album, and separate them to see the spread. 
joindf.sort_values(by='Year', axis=0, ascending=False)
plt.figure(figsize=(15,8))
p = sns.boxplot(x='AlbumName', y='UniqueWordsNS', data=joindf, palette=album_cdict)
p = sns.swarmplot(x='AlbumName', y='UniqueWordsNS', data=joindf, color="0.25")
plt.xticks(rotation=90);
plt.ylim((0,410));
plt.title('Unique Words in Each Album');

# %%
joindf.sort_values(by='Year', axis=0, ascending=False)
plt.figure(figsize=(15,8))
p = sns.boxplot(x='AlbumName', y='WordCountNS', data=joindf, palette=album_cdict)
p = sns.swarmplot(x='AlbumName', y='WordCountNS', data=joindf, color="0.25")
plt.xticks(rotation=90);
plt.ylim((0,3200));
plt.title('Number of Words in Each Album');

# %%
#Compare the relationship of unique words vs number of words. Looks quite linear.
wp = sns.jointplot(x='WordCountNS', y='UniqueWordsNS', data=joindf, height=10, kind='reg', )
plt.ylim((0,400));
plt.xlim((0,3200));
# Out:
# C:\Users\jlewis\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Or more clear, use 'hue' to separate the albums.
sns.lmplot(x='WordCountNS', y='UniqueWordsNS', hue='AlbumName', data=joindf, palette=album_cdict, height=11, aspect=1.2, fit_reg=False, legend_out=False,
          scatter_kws={'s':200, 'edgecolor':'black'})
plt.legend(loc=2)
plt.title('Unique Words Used vs Word Count')
plt.ylim(0,450);
plt.xlim(0,3500);

# %%
#Initial clustering attempts below. May need to do dimensionality reduction to make a more tangible clustering.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
vectorizer = TfidfVectorizer(max_features=10000, stop_words='english', max_df=0.1)

# %%
X = vectorizer.fit_transform(joindf['SongLyricsNS'])

# %%
km = KMeans(n_clusters=3, init='k-means++', n_init=1, verbose=1)

# %%
km.fit(X)
# Out:
# Initialization complete
# Iteration  0, inertia 475.173
# Iteration  1, inertia 240.652
# Iteration  2, inertia 240.629
# Converged at iteration 2: center shift 0.000000e+00 within tolerance 1.112811e-08
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=1, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=1)

# %%
terms = vectorizer.get_feature_names()

# %%
order_centroids = km.cluster_centers_.argsort()[:, ::-1]

# %%
for i in np.arange(0,3,1):
    for ind in order_centroids[i, :15]:
        print(' %s' % terms[ind], end='')
    print('\n')
# Out:
#  yes uh bye played attack boy mistake air blame spawn wouldnt pass liquor panic ho
#
#  wants today looks dream falling loves modern weve notes shell round walls ugly strong bar
#
#  la pretend spawn perfect family bam mask atmosphere noise paint air sweet blow bigger younger

# %%
############################### Sentiment Analysis ####################################
#Download the lexicon to be used
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\jlewis\AppData\Roaming\nltk_data...
# True

# %%
#Import sentiment package
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
#Check that the sentiment analyzer is working correctly
nltk_sentiment = SentimentIntensityAnalyzer()
score = nltk_sentiment.polarity_scores(joindf['SongLyricsNS'][0])
score
# Out:
# {'neg': 0.178, 'neu': 0.745, 'pos': 0.078, 'compound': -0.9885}

# %%
#Create a dataframe with the song names/lyrics and the scores
nltk_results = [nltk_sentiment.polarity_scores(row) for row in joindf['SongLyrics']]
sentiment_df = pd.DataFrame(nltk_results)
sentiment_df = pd.concat([joindf['SongName'], sentiment_df], axis=1)
resultsdf = pd.merge(joindf, sentiment_df, on='SongName')
resultsdf.head()
# Out:
#             SongName  AlbumID  SongResponse  \
# 0               1597     7391           200
# 1  Brief Description     7391           200
# 2     Current Status     7391           200
# 3      Complications     7391           200
# 4            4:30 AM     7391           200
#
#                                              SongURL  \
# 0          https://genius.com/Atmosphere-1597-lyrics
# 1  https://genius.com/Atmosphere-brief-descriptio...
# 2  https://genius.com/Atmosphere-current-status-l...
# 3  https://genius.com/Atmosphere-complications-ly...
# 4       https://genius.com/Atmosphere-4-30-am-lyrics
#
#                                           SongLyrics  \
# 0    henceforth step within my psychoanalysis cal...
# 1   sample have you heard it sing along if you di...
# 2   beyond now known as musab i peep rap city hig...
# 3   intro spawn spoken yo this is dedicated to th...
# 4   el p so tootsie roll the fuck back to your se...
#
#                                         SongLyricsNS  WordCount  UniqueWords  \
# 0  henceforth step within psychoanalysis callouse...       2828          300
# 1  sample heard sing along didnt hear youre gonna...       4504          425
# 2  beyond known musab peep rap city highlights ey...       3111          312
# 3  intro spawn spoken yo dedicated girl dated com...       3688          326
# 4  el p tootsie roll fuck back seat cause dont li...       2572          273
#
#    WordCountNS  UniqueWordsNS  PctUnique  AlbumName  Year  compound    neg  \
# 0         1869            242     12.948  Overcast!  1997   -0.9620  0.086
# 1         2844            349     12.271  Overcast!  1997   -0.9170  0.131
# 2         2008            256     12.749  Overcast!  1997   -0.9886  0.156
# 3         2356            264     11.205  Overcast!  1997   -0.9823  0.138
# 4         1613            214     13.267  Overcast!  1997   -0.9729  0.108
#
#      neu    pos
# 0  0.874  0.040
# 1  0.744  0.125
# 2  0.741  0.103
# 3  0.757  0.104
# 4  0.823  0.068

# %%
#Find the top 5 sentiments based on the compound scores
resultsdf.sort_values(by='compound', ascending=False).head(5)
# Out:
#                                         SongName  AlbumID  SongResponse  \
# 37                                  Godlovesugly     5005           200
# 34                                       Give Me     5005           200
# 115                                     Sunshine     6298           200
# 213  Let Me Know That You Know What You Want Now    31840           200
# 61                             Lift Her Pull Her     3262           200
#
#                                                SongURL  \
# 37   https://genius.com/Atmosphere-godlovesugly-lyrics
# 34        https://genius.com/Atmosphere-give-me-lyrics
# 115      https://genius.com/Atmosphere-sunshine-lyrics
# 213  https://genius.com/Atmosphere-let-me-know-that...
# 61   https://genius.com/Atmosphere-lifter-puller-ly...
#
#                                             SongLyrics  \
# 37    intro hey hey what are you doing over there i...
# 34    intro jimmy got shot in the parking lot  1 im...
# 115    1 aint no way to explain or say how painful ...
# 213   intro do you want respect or do you want trut...
# 61    spoken dialogue drunk woman do you really fee...
#
#                                           SongLyricsNS  WordCount  \
# 37   intro hey hey im standing come come im waiting...       3987
# 34   intro jimmy got shot parking lot 1 im slow typ...       3843
# 115  1 aint way explain say painful hangover today ...       2894
# 213  intro want respect want truth want respect wan...       3013
# 61   spoken dialogue drunk woman really feel honest...       4296
#
#      UniqueWords  WordCountNS  UniqueWordsNS  PctUnique  \
# 37           327         2883            262      9.088
# 34           310         2331            244     10.468
# 115          263         2010            218     10.846
# 213          245         1921            200     10.411
# 61           352         2784            283     10.165
#
#                    AlbumName  Year  compound    neg    neu    pos
# 37            God Loves Ugly  2002    0.9996  0.207  0.407  0.387
# 34            God Loves Ugly  2002    0.9995  0.070  0.685  0.245
# 115  Sad Clown Bad Summer #9  2007    0.9992  0.055  0.699  0.245
# 213              SouthSiders  2014    0.9989  0.060  0.686  0.254
# 61           Seven's Travels  2003    0.9982  0.062  0.785  0.153

# %%
#Find the lowest 5 sentiments based on the compound scores
resultsdf.sort_values(by='compound', ascending=True).head(5)
# Out:
#                                               SongName  AlbumID  SongResponse  \
# 109                                       Panic Attack     7187           200
# 57                                        Suicidegirls     3262           200
# 15                                              Primer     7391           200
# 87   I Wish Those Cats @ Fobia Would Give Me Some F...     7592           200
# 222                                          Pure Evil    43755           200
#
#                                                SongURL  \
# 109  https://genius.com/Atmosphere-panic-attack-lyrics
# 57   https://genius.com/Atmosphere-suicide-girls-ly...
# 15         https://genius.com/Atmosphere-primer-lyrics
# 87   https://genius.com/Atmosphere-i-wish-those-cat...
# 222     https://genius.com/Atmosphere-pure-evil-lyrics
#
#                                             SongLyrics  \
# 109   little mama got a little pill to swallow a li...
# 57    voice messages from upset girlfriends hey you...
# 15    begin hey daley get the fuck away from my sis...
# 87     tomorrows forecast flurries motherfucker sno...
# 222   chorus i b e no no no no no oh no no no i don...
#
#                                           SongLyricsNS  WordCount  \
# 109  little mama got little pill swallow little wat...       2778
# 57   voice messages upset girlfriends hey fucking a...       2156
# 15   begin hey daley get fuck away sister punk moth...       2368
# 87   tomorrows forecast flurries motherfucker snowm...       4095
# 222  chorus b e oh dont believe dont believe oh pur...       1490
#
#      UniqueWords  WordCountNS  UniqueWordsNS  PctUnique  \
# 109          237         1652            185     11.199
# 57           222         1381            163     11.803
# 15           265         1512            208     13.757
# 87           357         2686            295     10.983
# 222          151          865            105     12.139
#
#                           AlbumName  Year  compound    neg    neu    pos
# 109  Happy Clown Bad Dub 8 / Fun EP  2006   -0.9993  0.291  0.598  0.112
# 57                  Seven's Travels  2003   -0.9988  0.261  0.677  0.062
# 15                        Overcast!  1997   -0.9987  0.230  0.702  0.068
# 87                 Headshots: SE7EN  2005   -0.9986  0.185  0.735  0.080
# 222                   Fishing Blues  2016   -0.9983  0.345  0.590  0.065

# %%
#Take a look at the distributions from the vader sentiment analysis
fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(16,8))
resultsdf['compound'].hist(bins=40, ax=ax[0,0])
ax[0,0].set_xlabel('Compound')
resultsdf['neg'].hist(bins=40, color='red', ax=ax[0,1])
ax[0,1].set_xlabel('Negative')
resultsdf['neu'].hist(bins=40, color='grey', ax=ax[1,0])
ax[1,0].set_xlabel('Neutral')
resultsdf['pos'].hist(bins=40, color='green', ax=ax[1,1])
ax[1,1].set_xlabel('Positive');
fig.suptitle('Distributions of the Sentiment Analysis');

# %%
#Going to try and cluster based on the sentiment columns.
sent_X = resultsdf[['neg', 'pos', 'neu', 'compound']]

# %%
#Check optimal cluster number using the elbow method
wcss = []
for i in np.arange(1,15,1):
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, verbose=0)
    km.fit(sent_X)
    wcss.append(km.inertia_)

# %%
#Plot the elbow method
plt.scatter(x=np.arange(1,15,1), y=wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS');

# %%
#Fit KMeans using 3 clusters.
km = KMeans(n_clusters=3, init='k-means++', n_init=10, verbose=0)
km.fit(sent_X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
resultsdf['Cluster'] = km.predict(sent_X)

# %%
#Looks almost all the clusters do actually catch many different songs.
resultsdf['Cluster'].value_counts()
# Out:
# 0    117
# 1    114
# 2     19
# Name: Cluster, dtype: int64

# %%
#Look for a correlation between the cluster numbers and the neg/pos/neu columns.
corr = resultsdf[['Cluster', 'neg', 'pos', 'neu', 'compound']].corr()
sns.heatmap(corr, cbar=False, annot=True)

# %%
#Make new columns for the album df to plot pcts of each topic in each album
ids = resultsdf['AlbumID'].unique().tolist()
pcts1 = []
pcts2 = []
pcts3 = []
for i in ids:
    df = resultsdf[resultsdf['AlbumID']==i]
    pcts1.append(len(df[df['Cluster']==0])/len(df))
    pcts2.append(len(df[df['Cluster']==1])/len(df))
    pcts3.append(len(df[df['Cluster']==2])/len(df))

albumdf['Pct1'] = pcts1
albumdf['Pct2'] = pcts2
albumdf['Pct3'] = pcts3

albumdf.head()
# Out:
#                        AlbumName  AlbumID  Year      Pct1      Pct2    Pct3
# 0                      Overcast!     7391  1997  0.125000  0.812500  0.0625
# 1  Lucy Ford: The Atmosphere EPs     5001  2001  0.750000  0.187500  0.0625
# 2                 God Loves Ugly     5005  2002  0.555556  0.444444  0.0000
# 3                Seven's Travels     3262  2003  0.550000  0.450000  0.0000
# 4               Headshots: SE7EN     7592  2005  0.320000  0.680000  0.0000

# %%
#Make the plot
albumdf.plot(kind='bar', x='AlbumName', y=['Pct1', 'Pct2', 'Pct3'], stacked=True, figsize=(10,6), title='Cluster Distribution in Each Album')
