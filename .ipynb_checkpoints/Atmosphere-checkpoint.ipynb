# %%
import pandas as pd
import numpy as np
import requests
import urllib
import re
import string
from bs4 import BeautifulSoup

# %%
#Open the page with all albums.
main_page = 'https://www.azlyrics.com/a/atmosphere.html'
try:
    content = urllib.request.urlopen(main_page).read()
    main_soup = BeautifulSoup(content, 'html.parser')
except Exception as e:
    print('Error'+str(e))
#Pull the list of albums on the page and the associated IDs.
album_list = main_soup.find(id='listAlbum')
albums = [name.string.strip('\"') for name in album_list.findAll('b')]
album_ids = [number.get('id') for number in album_list.findAll(['a']) if len(number)==0]

# %%
#Create a dataframe containing each album and the ID
albumdf = pd.DataFrame(data={'AlbumName': albums, 'AlbumID': album_ids})
albumdf
# Out:
#                                             AlbumName AlbumID
# 0                                           Overcast!    7391
# 1                       Lucy Ford: The Atmosphere EPs    5001
# 2                                      God Loves Ugly    5005
# 3                                     Seven's Travels    3262
# 4                                    Headshots: SE7EN    7592
# 5         You Can't Imagine How Much Fun We're Having    5146
# 6                      Happy Clown Bad Dub 8 / Fun EP    7187
# 7                             Sad Clown Bad Summer #9    6298
# 8                              Sad Clown Bad Fall #10    7048
# 9                            Sad Clown Bad Winter #11    7050
# 10                                   Strictly Leakage    6710
# 11  When Life Gives You Lemons, You Paint That Shi...    6684
# 12                           Sad Clown Bad Spring #12    7049
# 13                                       Leak At Will    7568
# 14  To All My Friends, Blood Makes The Blade Holy ...   10118
# 15                                    The Family Sign   15442
# 16                                        SouthSiders   31840
# 17                                      Fishing Blues   43755

# %%
#Need to implement loop/vectorize (if possible) so it can be done on every album.
album_dicts = dict.fromkeys(albumdf['AlbumID'])
for i,j in enumerate(albumdf['AlbumID']):
    #Find the album
    findalbum = album_list.findAll(class_='album')[i]
    #Initialize song list
    songs = []
    #Find where the song titles begin
    title = findalbum.findNext('a', text=True)
    #Loop through the list until reaching the next album, where there is an ID field.
    if i < len(albumdf)-1:
        while title.get('id') != albumdf['AlbumID'][i+1]:
            songs.append(title.text)
            title = title.findNext('a')
        album_dicts[j] = songs
    else:
        while title.text != 'A Long Hello':
            songs.append(title.text)
            title = title.findNext('a')
        album_dicts[j] = songs

# %%
#Add song counts to the albumdf
albumdf['Songs'] = albumdf['AlbumID'].apply(lambda idn: len(album_dicts[idn]))

# %%
all_songs = [name for sublist in album_dicts.values() for name in sublist]
songdf = pd.DataFrame({'SongName': all_songs})
songdf['SongName']
# Out:
# 0                                             1597
# 1                                Brief Description
# 2                                   Current Status
# 3                                    Complications
# 4                                          4:30 AM
# 5                                           Adjust
# 6                                             Clay
# 7                               Sound Is Vibration
# 8                                        Multiples
# 9                                        Scapegoat
# 10                                             WND
# 11                             Multiples (Reprise)
# 12                                        Caved In
# 13                           Cuando Limpia El Humo
# 14                                    The Outernet
# 15                                          Primer
# 16                               Between The Lines
# 17                                      Like Today
# 18                             Tears For The Sheep
# 19                             Guns And Cigarettes
# 20                Don't Ever Fucking Question That
# 21                                         It Goes
# 22                            If I Was Santa Claus
# 23                              Aspiring Sociopath
# 24                                    Free Or Dead
# 25                    Party For The Fight To Write
# 26         Mama Had A Baby And His Head Popped Off
# 27                   They're All Gonna Laugh @ You
# 28                                  Lost And Found
# 29               The Woman With The Tattooed Hands
#                           ...
# 206                                 Mrs. Interpret
# 207                                      Fortunate
# 208                                     Kanye West
# 209                       We Ain't Gonna Die Today
# 210                            My Lady Got Two Men
# 211                                        Flicker
# 212                         January On Lake Street
# 213    Let Me Know That You Know What You Want Now
# 214                 She Don't Know Why She Love It
# 215                                           Hell
# 216                     I Don't Need No Fancy Shit
# 217                                          Idiot
# 218                                Prelude To Hell
# 219                                    Like A Fire
# 220                                          Ringo
# 221                                          Besos
# 222                                      Pure Evil
# 223                                        Perfect
# 224                                  Seismic Waves
# 225                                    Next To You
# 226               The Shit That We've Been Through
# 227                         When The Lights Go Out
# 228                                      No Biggie
# 229                                     Everything
# 230                               Chasing New York
# 231                                          Sugar
# 232                                  Fishing Blues
# 233                                Won't Look Back
# 234                        Anybody That I've Known
# 235                                  Still Be Here
# Name: SongName, Length: 236, dtype: object

# %%
#Function to clean up the song names
def clean_names(string):
    pattern = re.compile('[\W_]+')
    string = pattern.sub('', string.lower())
    return string

# %%
#Create a new column with the cleaned up names
songdf['CleanedName'] = songdf['SongName'].apply(lambda song: clean_names(song))
#And another for the different song pages
songdf['SongPage'] = songdf['CleanedName'].apply(
    lambda name: 'https://www.azlyrics.com/lyrics/atmosphere/'+name+'.html')
songdf
# Out:
#                                         SongName  \
# 0                                           1597
# 1                              Brief Description
# 2                                 Current Status
# 3                                  Complications
# 4                                        4:30 AM
# 5                                         Adjust
# 6                                           Clay
# 7                             Sound Is Vibration
# 8                                      Multiples
# 9                                      Scapegoat
# 10                                           WND
# 11                           Multiples (Reprise)
# 12                                      Caved In
# 13                         Cuando Limpia El Humo
# 14                                  The Outernet
# 15                                        Primer
# 16                             Between The Lines
# 17                                    Like Today
# 18                           Tears For The Sheep
# 19                           Guns And Cigarettes
# 20              Don't Ever Fucking Question That
# 21                                       It Goes
# 22                          If I Was Santa Claus
# 23                            Aspiring Sociopath
# 24                                  Free Or Dead
# 25                  Party For The Fight To Write
# 26       Mama Had A Baby And His Head Popped Off
# 27                 They're All Gonna Laugh @ You
# 28                                Lost And Found
# 29             The Woman With The Tattooed Hands
# ..                                           ...
# 206                               Mrs. Interpret
# 207                                    Fortunate
# 208                                   Kanye West
# 209                     We Ain't Gonna Die Today
# 210                          My Lady Got Two Men
# 211                                      Flicker
# 212                       January On Lake Street
# 213  Let Me Know That You Know What You Want Now
# 214               She Don't Know Why She Love It
# 215                                         Hell
# 216                   I Don't Need No Fancy Shit
# 217                                        Idiot
# 218                              Prelude To Hell
# 219                                  Like A Fire
# 220                                        Ringo
# 221                                        Besos
# 222                                    Pure Evil
# 223                                      Perfect
# 224                                Seismic Waves
# 225                                  Next To You
# 226             The Shit That We've Been Through
# 227                       When The Lights Go Out
# 228                                    No Biggie
# 229                                   Everything
# 230                             Chasing New York
# 231                                        Sugar
# 232                                Fishing Blues
# 233                              Won't Look Back
# 234                      Anybody That I've Known
# 235                                Still Be Here
#
#                             CleanedName  \
# 0                                  1597
# 1                      briefdescription
# 2                         currentstatus
# 3                         complications
# 4                                 430am
# 5                                adjust
# 6                                  clay
# 7                      soundisvibration
# 8                             multiples
# 9                             scapegoat
# 10                                  wnd
# 11                     multiplesreprise
# 12                              cavedin
# 13                   cuandolimpiaelhumo
# 14                          theouternet
# 15                               primer
# 16                      betweenthelines
# 17                            liketoday
# 18                     tearsforthesheep
# 19                    gunsandcigarettes
# 20          donteverfuckingquestionthat
# 21                               itgoes
# 22                     ifiwassantaclaus
# 23                    aspiringsociopath
# 24                           freeordead
# 25              partyforthefighttowrite
# 26      mamahadababyandhisheadpoppedoff
# 27               theyreallgonnalaughyou
# 28                         lostandfound
# 29         thewomanwiththetattooedhands
# ..                                  ...
# 206                        mrsinterpret
# 207                           fortunate
# 208                           kanyewest
# 209                 weaintgonnadietoday
# 210                     myladygottwomen
# 211                             flicker
# 212                 januaryonlakestreet
# 213  letmeknowthatyouknowwhatyouwantnow
# 214             shedontknowwhysheloveit
# 215                                hell
# 216                idontneednofancyshit
# 217                               idiot
# 218                       preludetohell
# 219                           likeafire
# 220                               ringo
# 221                               besos
# 222                            pureevil
# 223                             perfect
# 224                        seismicwaves
# 225                           nexttoyou
# 226          theshitthatwevebeenthrough
# 227                  whenthelightsgoout
# 228                            nobiggie
# 229                          everything
# 230                      chasingnewyork
# 231                               sugar
# 232                        fishingblues
# 233                        wontlookback
# 234                 anybodythativeknown
# 235                         stillbehere
#
#                                               SongPage
# 0    https://www.azlyrics.com/lyrics/atmosphere/159...
# 1    https://www.azlyrics.com/lyrics/atmosphere/bri...
# 2    https://www.azlyrics.com/lyrics/atmosphere/cur...
# 3    https://www.azlyrics.com/lyrics/atmosphere/com...
# 4    https://www.azlyrics.com/lyrics/atmosphere/430...
# 5    https://www.azlyrics.com/lyrics/atmosphere/adj...
# 6    https://www.azlyrics.com/lyrics/atmosphere/cla...
# 7    https://www.azlyrics.com/lyrics/atmosphere/sou...
# 8    https://www.azlyrics.com/lyrics/atmosphere/mul...
# 9    https://www.azlyrics.com/lyrics/atmosphere/sca...
# 10   https://www.azlyrics.com/lyrics/atmosphere/wnd...
# 11   https://www.azlyrics.com/lyrics/atmosphere/mul...
# 12   https://www.azlyrics.com/lyrics/atmosphere/cav...
# 13   https://www.azlyrics.com/lyrics/atmosphere/cua...
# 14   https://www.azlyrics.com/lyrics/atmosphere/the...
# 15   https://www.azlyrics.com/lyrics/atmosphere/pri...
# 16   https://www.azlyrics.com/lyrics/atmosphere/bet...
# 17   https://www.azlyrics.com/lyrics/atmosphere/lik...
# 18   https://www.azlyrics.com/lyrics/atmosphere/tea...
# 19   https://www.azlyrics.com/lyrics/atmosphere/gun...
# 20   https://www.azlyrics.com/lyrics/atmosphere/don...
# 21   https://www.azlyrics.com/lyrics/atmosphere/itg...
# 22   https://www.azlyrics.com/lyrics/atmosphere/ifi...
# 23   https://www.azlyrics.com/lyrics/atmosphere/asp...
# 24   https://www.azlyrics.com/lyrics/atmosphere/fre...
# 25   https://www.azlyrics.com/lyrics/atmosphere/par...
# 26   https://www.azlyrics.com/lyrics/atmosphere/mam...
# 27   https://www.azlyrics.com/lyrics/atmosphere/the...
# 28   https://www.azlyrics.com/lyrics/atmosphere/los...
# 29   https://www.azlyrics.com/lyrics/atmosphere/the...
# ..                                                 ...
# 206  https://www.azlyrics.com/lyrics/atmosphere/mrs...
# 207  https://www.azlyrics.com/lyrics/atmosphere/for...
# 208  https://www.azlyrics.com/lyrics/atmosphere/kan...
# 209  https://www.azlyrics.com/lyrics/atmosphere/wea...
# 210  https://www.azlyrics.com/lyrics/atmosphere/myl...
# 211  https://www.azlyrics.com/lyrics/atmosphere/fli...
# 212  https://www.azlyrics.com/lyrics/atmosphere/jan...
# 213  https://www.azlyrics.com/lyrics/atmosphere/let...
# 214  https://www.azlyrics.com/lyrics/atmosphere/she...
# 215  https://www.azlyrics.com/lyrics/atmosphere/hel...
# 216  https://www.azlyrics.com/lyrics/atmosphere/ido...
# 217  https://www.azlyrics.com/lyrics/atmosphere/idi...
# 218  https://www.azlyrics.com/lyrics/atmosphere/pre...
# 219  https://www.azlyrics.com/lyrics/atmosphere/lik...
# 220  https://www.azlyrics.com/lyrics/atmosphere/rin...
# 221  https://www.azlyrics.com/lyrics/atmosphere/bes...
# 222  https://www.azlyrics.com/lyrics/atmosphere/pur...
# 223  https://www.azlyrics.com/lyrics/atmosphere/per...
# 224  https://www.azlyrics.com/lyrics/atmosphere/sei...
# 225  https://www.azlyrics.com/lyrics/atmosphere/nex...
# 226  https://www.azlyrics.com/lyrics/atmosphere/the...
# 227  https://www.azlyrics.com/lyrics/atmosphere/whe...
# 228  https://www.azlyrics.com/lyrics/atmosphere/nob...
# 229  https://www.azlyrics.com/lyrics/atmosphere/eve...
# 230  https://www.azlyrics.com/lyrics/atmosphere/cha...
# 231  https://www.azlyrics.com/lyrics/atmosphere/sug...
# 232  https://www.azlyrics.com/lyrics/atmosphere/fis...
# 233  https://www.azlyrics.com/lyrics/atmosphere/won...
# 234  https://www.azlyrics.com/lyrics/atmosphere/any...
# 235  https://www.azlyrics.com/lyrics/atmosphere/sti...
#
# [236 rows x 3 columns]

# %%
#Next, get a lexicon for every song by iterating through the pages.
#Also find a way to associate an album with every song in the songdf.

# %%
#Find key based on name in a list? -> extend this idea.
k1 = list(album_dicts.keys())[0]
s = '1597'
[s in album_dicts[k1]]
# Out:
# [True]
